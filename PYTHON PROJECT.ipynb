# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhi124github/foss-practical-5/blob/main/PYTHON%20PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#taking customers personal details

print()
print()
print(" FOOD ORDERING APP ".center(120,"-"))
print()
print("welcome".center(120,"~"))
name=input("ENTER YOUR NAME:")
call=int(input("ENTER YOUR Number:"))
add=input("ENTER YOUR DELIVERY ADDRESS:")
print()
print("thank you for joining with us".center(120," "))

print()
print()


# MENU

print(120*"~")
print(" FAMILY RESTAURANT ".center(120,"-"))
print(" MENU".center(120," "))
print()
print(" DRINKS  & ICE CREAM                        INDIAN MAIN COURSE")
print("1.COKE................70/-           NON VEG ")
print("2.MANGO SHAKE.........120/-     8.EGG CURRY..........90/- ")
print("3.SPRITE..............75/-      9.OMELETTE...........50/-")
print("4.LEMON JUICE.........40/-      10.FISH CURRY.........120/-")
print("5.CHOCLATE ICE CREAM..70/-      11.FISH FRIED.........160/-")
print("6.KESAR PISTA.........120/-     12.CHICKEN CURRY......180/-")
print("7.DRY FRUIT FALLOODA...250/-     13.CHICKEN BUTTER MASLA..200/-")
print()
print("RICE & FLAT BREAD                     VEG ")
print("14.CHICKEN BIRYANI.......250/-     18.PANEER MAKNI.........120/-")
print("15.PULAV...............160/-       19.PALAK PANNER.........128/-")
print("16.JEERA RICE.......60/-           20.VEG HANDI............200/-")
print("17.MUTTON BIRYANI......300/-       21.VEG KOLHAPURI.........250/-")
print()
print("SNACKS                               CAKE & SWEET DISH")
print("22.BURGER................120/-      25.RED VELVET..........50/-")
print("23.FRIES.................70/-       26.CHOCLATE BROWNIE...80/-")
print("24.CHICKEN NUGGET........100/-      27.MALAI SANDWICH.....120/-")
print()
print()
print("CUSTOMER IS OUR GOD ".center(120,"-"))
print()
print()
print(120*"~")


print("    PLEASE SELECT YOUR DISH    ")


def  coke():
    print("COKE")
    prod_name = "COKE"
    price = 70
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  mangoshake():
    print("MANGO SHAKE")
    prod_name = "MANGO SHAKE"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  sprite():
    print("SPRITE")
    prod_name = "SPRITE"
    price = 75
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  lemonjuice():
    print(" LEMON JUICE")
    prod_name = "LEMON JUICE"
    price = 40
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  choclateicecream():
    print(" CHOCLATE ICE CREAM")
    prod_name = "CHOCLATE ICE CREAM"
    price = 70
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  kesarpista():
    print(" KESAR PISTA")
    prod_name = "KESAR PISTA"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def  dryfruit ():
    print("DRY FRUIT FALOODA ")
    prod_name = "DRY FRUIT FALOODA"
    price = 250
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def biryani():
    print("CHICKEN BIRYANI")
    prod_name = "CHICKEN BIRYANI"
    price = 250
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def pulav():
    print("PULAV")
    prod_name = "PULAV"
    price = 160
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def jeerarice():
    print("JEERA RICE")
    prod_name = "JEERA RICE"
    price = 60
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def muttonbir():
    print(" MUTTON BIRYANI")
    prod_name = "MUTTON BIRYANI"
    price = 300
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def eggcurry():
    print(" EGG CURRY")
    prod_name = "EGG CURRY"
    price = 90
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def omlete():
    print(" EGG OMLETE")
    prod_name = "EGG OMLETE"
    price = 50
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def fishcurry():
    print("FISAH CURRY")
    prod_name = "FISAH CURRY"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def friedfish():
    print(" FRIED FISH")
    prod_name = "FRIED FISH"
    price = 160
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def CHICURRY():
    print("CHICKEN CURRY")
    prod_name = "CHICKEN CURRY"
    price = 180
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def CHIBUTMASS():
    print("CHICKEN BUTTER MASALA")
    prod_name = "CHICKEN BUTTER MASALA"
    price = 200
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def SWEETSANDWICH():
    print("MALAI SANDWICH")
    prod_name = "MALAI SANDWICH"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def CHOCOBROWNIE():
    print("CHOCLATE BROWNIE")
    prod_name = "CHOCLATE BROWNIE"
    price = 80
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def VELVET():
    print("RED VELVET CAKE")
    prod_name = "RED VELVET CAKE"
    price = 50
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def KOLAPURI():
    print("VEG KHOLAPURI")
    prod_name = "VEG KHOLAPURI"
    price = 250
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def HANDI():
    print("VEG HANDI")
    prod_name = "VEG HANDI"
    price = 200
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def PALAKPAN():
    print("PALAK PANNER")
    prod_name = "PALAK PANNER"
    price = 128
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def PANEERMAKH():
    print("PANEER MAKHNI")
    prod_name = "PANEER MAKHNI"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)
def burger():
    print("burger")
    prod_name = "burger"
    price = 120
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)


def FRIES ():
    print("FRIES")
    prod_name = "fRIES"
    price = 70
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)

def nugget():
    print("CHICKEN NUGGET")
    prod_name = "CHICKEN NUGGET"
    price = 100
    quantity = int(input("Enter no. of quantity:"))
    BasicAmt = price * quantity
    gstAmt = BasicAmt * 0.5
    TotalAmt = gstAmt + BasicAmt
    return(prod_name,price,quantity,BasicAmt,gstAmt,TotalAmt)






def bill(product_name, price, quantity, basic_amount, gst_amount, total_amount):
    print("INVOICE".center(20,"_"))
    print(f"Product Name: {product_name}")
    print(f"Price per item: {price}")
    print(f"Quantity: {quantity}")
    print(f"Basic Amount: {basic_amount}")
    print(f"GST Amount: {gst_amount}")
    print(f"Total Amount: {total_amount}")
    print("\n")

# Create an empty list to store items in the cart
cart = []


print()
print()
print(" FOR MAKING BILL ENTER INDEX NUMBER 28")
while True:
    choice = int(input("Enter your dish index number"))
    if choice == 1:
       cart.append(coke())

    if choice == 2:
       cart.append(mangoshake())

    if choice == 3:
       cart.append(sprite())

    if choice == 4:
        cart.append(lemonjuice())

    if choice == 5:
        cart.append(choclateicecream())
    if choice == 6:
        cart.append(kesarpista())

    if choice == 7:
        cart.append(dryfruit())
    if choice == 24:
        cart.append(nugget())
    if choice == 22:
        cart.append(burger())
    if choice == 23:
        cart.append(FRIES())

    if choice == 8:
        cart.append(eggcurry())

    if choice == 9:
        cart.append(omlete())
    if choice == 10:
        cart.append(fishcurry())
    if choice == 11:
        cart.append(friedfish())
    if choice == 12:
       cart.append( CHICURRY())
    if choice == 13:
       cart.append(CHICURRY())
    if choice == 14:
        cart.append(biryani())
    if choice == 15:
        cart.append(pulav())
    if choice == 16:
        cart.append(jeerarice())
    if choice == 17:
        cart.append(muttonbir())
    if choice == 18:
        cart.append(PANEERMAKH())
    if choice == 19:
        cart.append(PALAKPAN())
    if choice == 20:
        cart.append(HANDI())
    if choice == 21:
        cart.append(KOLAPURI())
    if choice == 25:
         cart.append(VELVET())
    if choice == 26:
        cart.append(CHOCOBROWNIE())
    if choice == 27:
        cart.append(SWEETSANDWICH())
    elif choice == 28:
         break


# Calculate and print the total bill
total_bill = sum(item[5] for item in cart)
print("\n===== Your Bill =====")
for item in cart:
    bill(*item)
print("=====================")
print(f"Total Bill Amount: {total_bill:.2f}")

print()
print()
print(" YOUR ORDER IS PLACED THANKYOU FOR VISITING US ".center (140,"~"))
# Out:
# -------------------------------------------------- FOOD ORDERING APP ---------------------------------------------------
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~welcome~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ENTER YOUR NAME:siddhi naik
# ENTER YOUR Number:2321245
# ENTER YOUR DELIVERY ADDRESS:sasntascruzx
#
#                                              thank you for joining with us
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# -------------------------------------------------- FAMILY RESTAURANT ---------------------------------------------------
#                                                           MENU
#
#  DRINKS  & ICE CREAM                        INDIAN MAIN COURSE
# 1.COKE................70/-           NON VEG
# 2.MANGO SHAKE.........120/-     8.EGG CURRY..........90/-
# 3.SPRITE..............75/-      9.OMELETTE...........50/-
# ...
